# %%
import tensorflow as tf
import cv_io

# %%
preprocessed_folder = '/DATA/Dropbox/LOOTRPV/Personal_programming/MachineLearning/Tutorials/ImageRecognition/data_preprocessed'

# %%
imgs, labels, nclass = cv_io.image_batch_handle(preprocessed_folder)

# %%
import matplotlib.pyplot as plt
plt.clf()
with tf.Session() as sess:
    for i in range(1):
        _imgs, _labels = sess.run([imgs, labels])
        for img in _imgs:
            plt.imshow(img[:,:,0])
            plt.colorbar()
            plt.show()
            plt.close()

# %%
print(nclass)
# Out:
# {'dogs': 791, 'cats': 1127}
