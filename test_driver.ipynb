# %%
import tensorflow as tf
import cv_io

# %%
preprocessed_folder = '/DATA/Dropbox/LOOTRPV/Personal_programming/MachineLearning/Tutorials/ImageRecognition/data_preprocessed'

# %%
imgs, labels, nclass, class2label, label2class = cv_io.image_batch_handle(preprocessed_folder)

# %%
import matplotlib.pyplot as plt
plt.clf()
with tf.Session() as sess:
    for i in range(1):
        _imgs, _labels = sess.run([imgs, labels])
        print(_labels)
        for img in _imgs:
            plt.imshow(img[:,:,0])
            plt.colorbar()
            plt.show()
            plt.close()
# Out:
# [[1. 0.]
#  [1. 0.]
#  [0. 1.]
#  [1. 0.]]

# %%
print(nclass)
# Out:
# {'dogs': 791, 0: 791, 'cats': 1127, 1: 1127}

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import numpy as np
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
x = np.linspace(0,100, 100)
y = np.sin(x)
iplot([go.Scatter(x=x, y=y, mode='markers'),
      go.Histogram2dContour(x=x, y=y, contours=go.Contours(coloring='heatmap'))])
# Out:
# <div id="97213ce2-920e-4a5e-b28f-527306cb61cb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("97213ce2-920e-4a5e-b28f-527306cb61cb")) {
# ...

# %%
import pandas as pd
logfile = "/DATA/Dropbox/LOOTRPV/Personal_programming/MachineLearning/Tutorials/ImageRecognition/workspace/AlexNet_zero.log"
df = pd.read_csv(logfile, sep='\t')

# %%
df.head()
# Out:
#    Epoch  AvgTrainLoss  AvgTrainAcc  AvgValLoss  AvgValAcc
# 0      1      0.693141     0.298828    0.692791   0.281250
# 1      2      0.691154     0.757650    0.686912   0.569822
# 2      3      0.674217     0.693778    0.752069   0.584040
# 3      4      0.696124     0.655490    0.671434   0.587597
# 4      5      0.679270     0.636256    0.689717   0.588440

# %%
from plotly import tools
fig = tools.make_subplots(rows=2, cols=1, subplot_titles=('Loss', 'Accuracy'))
fig.append_trace(go.Scatter(x=df.Epoch, y=df.AvgTrainLoss, name='Train', line=dict(color='#1F77B4')), 1,1)
fig.append_trace(go.Scatter(x=df.Epoch, y=df.AvgValLoss, name='Val', line=dict(color='#FF7F0E')), 1,1)
fig.append_trace(go.Scatter(x=df.Epoch, y=df.AvgTrainAcc, name='Train', showlegend=False, line=dict(color='#1F77B4')), 2,1)
fig.append_trace(go.Scatter(x=df.Epoch, y=df.AvgValAcc, name='Val', showlegend=False, line=dict(color='#FF7F0E')), 2,1)
fig['layout']['xaxis2'].update(title='Epoch')
iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x2,y2 ]
# <div id="85b5d780-c904-47f2-b4a8-863828542afe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("85b5d780-c904-47f2-b4a8-863828542afe")) {
# ...
